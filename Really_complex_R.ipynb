# %% [markdown]
# # Example R in Jupyter
#
# Hey look a code block

# %%
 suppressMessages(library(ggplot2))

# %% [markdown]
# Here is a nice piece of description for this plot

# %%
ggplot() +
geom_point(aes(x=6,
               y=5),
           col="green")
# Out:
# plot without title

# %% [markdown]
# Closing analysis notes here
